# %%
# contains a function called glob that searches for files 
# and directories whose names match a pattern
import glob

# %%
print(glob.glob('inflammation*.csv'))
# Out:
# ['inflammation-05.csv', 'inflammation-11.csv', 'inflammation-10.csv', 'inflammation-04.csv', 'inflammation-12.csv', 'inflammation-06.csv', 'inflammation-07.csv', 'inflammation-03.csv', 'inflammation-02.csv', 'inflammation-01.csv', 'inflammation-09.csv', 'inflammation-08.csv']

# %%
import numpy
import matplotlib.pyplot

filenames = sorted(glob.glob('inflammation*.csv'))
filenames = filenames[0:3]

for f in filenames:
    print(f)
    
    data = numpy.loadtxt(fname=f, delimiter=',')
    
    fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))
    
    axes1 = fig.add_subplot(1, 3, 1)
    axes2 = fig.add_subplot(1, 3, 2)
    axes3 = fig.add_subplot(1, 3, 3)
    
    axes1.set_ylabel('AVERAGE')
    axes1.set_xlabel('DAYS')
    axes1.plot(numpy.mean(data, axis=0), drawstyle='steps-mid')
    
    axes2.set_ylabel('MAX')
    axes2.set_xlabel('DAYS')
    axes2.plot(numpy.max(data, axis=0), drawstyle='steps-mid')
    
    axes3.set_ylabel('MIN')
    axes3.set_xlabel('DAYS')
    axes3.plot(numpy.min(data, axis=0), drawstyle='steps-mid')
    
    fig.tight_layout()
    matplotlib.pyplot.show()
# Out:
# inflammation-01.csv
# inflammation-02.csv
# inflammation-03.csv

# %%
filenames = sorted(glob.glob('inflammation*.csv'))
filenames = filenames[0:2]


data1 = numpy.loadtxt(fname=filenames[0], delimiter=',')
data2 = numpy.loadtxt(fname=filenames[1], delimiter=',')

fig = matplotlib.pyplot.figure(figsize=(5.0, 3.0))
matplotlib.pyplot.ylabel('Difference in Mean')
matplotlib.pyplot.xlabel('DAYS')
matplotlib.pyplot.plot(numpy.mean(data1, axis=0)-numpy.mean(data2, axis=0), drawstyle='steps-mid')

fig.tight_layout()
matplotlib.pyplot.show()

# %%
filenames = sorted(glob.glob('inflammation*.csv'))
composite_data = numpy.zeros((60,40))

for f in filenames:
    # sum each new file's data into composite_data as it's read
    # and then divide the composite_data by number of samples
    composite_data += numpy.loadtxt(fname=f, delimiter=',')
    
composite_data /= len(filenames)

fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))
axes1 = fig.add_subplot(1, 3, 1)
axes2 = fig.add_subplot(1, 3, 2)
axes3 = fig.add_subplot(1, 3, 3)

axes1.set_ylabel('AVERAGE')
axes1.set_xlabel('DAYS')
axes1.plot(numpy.mean(composite_data, axis=0), drawstyle='steps-mid') # subplot of the average inflammation per day

axes2.set_ylabel('MAX')
axes2.set_xlabel('DAYS')
axes2.plot(numpy.max(composite_data, axis=0), drawstyle='steps-mid') # subplot of the maximum inflammation per day

axes3.set_ylabel('MIN')
axes3.set_xlabel('DAYS')
axes3.plot(numpy.min(composite_data, axis=0), drawstyle='steps-mid') # subplot of the minimum inflammation per day

fig.tight_layout()

matplotlib.pyplot.show()
